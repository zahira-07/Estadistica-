# %% [markdown]
# <a href="https://colab.research.google.com/github/zahira-07/Estadistica-/blob/main/ei_u2_01_23150199.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#a) revisa si el dataset tiene valores nulos mediante df.info(), en dado caso, aplica df.dropna(inplace = True).

import pandas as pd
import numpy as np

df = pd.read_csv("https://raw.githubusercontent.com/zahira-07/Estadistica-/refs/heads/main/data%20(2).csv")
df.dropna(inplace = True)
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [164 rows x 4 columns]

# %%
print(df.isna ().sum())
df = df.dropna()


import seaborn as sns
import matplotlib.pyplot as plt


correlation_matrix - df.corr()
plt.figure(figsize=(15, 9))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", square=True, cbar_kws={"shrink": 0.8})
plt.title('Mapa de Calor de la Matriz de Correlación')

x = df[["Duration", "Maxpulse"]]
y = df ["Calories"]

import statsmodels.api as sm
x_constante = sm.add_constant(x)
modelo = sm.OLS(Y, x_constante).fit()

Yc = modelo.predict(x_constante)


plt. figure()
plt.scatter(Y, Yc)
plt. xlabel ("Valores reales")
plt.ylabel ("Valores predichos")
plt. title("Comparación de valores reales vs. predichos")
plt.show

from sklearn.metrics import r2_score
r2=r2_score(Y,Yc)
print ("f'Coeficiente de determinación: (r2: 8.4f) /n" )


residuales =modelo.resid
from scipy.stats import shapiro
_, valor_p_sh = shapiro(residuales)
print ("f'valor-p de Shapiro: (valor_p_sh: 0.14f) \n*" )
# Se rechaza H0



from statsmodels.stats.api import het_breuschpagan
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor_p de Breusch-Pagan: (valor_P_bp: 0.14f)\n')
# Se rechaza H0 el valor es muy bajo.
# Conclusion: El modelo tiene un buen ajuste general. Los residuales no son normales, lo que sugiere que el modelo puede no ser adecuado
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    0
# dtype: int64
# f'Coeficiente de determinación: (r2: 8.4f) /n
# f'valor-p de Shapiro: (valor_p_sh: 0.14f)
# *
# valor_p de Breusch-Pagan: (valor_P_bp: 0.14f)
